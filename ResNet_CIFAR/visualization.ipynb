# %%
import os
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
# Folder containing your .pt result files
results_dir = "./results"  # Change to your actual path

methods = ["Random", "Localize", "SJLT", "FJLT", "Loc-32768_SJLT", "Loc-32768_Gaussian", "Loc-131072_SJLT", "Loc-131072_Gaussian", "Rand-32768_SJLT", "Rand-32768_Gaussian", "Rand-131072_SJLT", "Rand-131072_Gaussian"]
dims = [2048, 4096, 8192]

# Initialize dictionaries to store the results
lds_data = {method: [] for method in methods}
proj_time_data = {method: [] for method in methods}

# Load results from files
for method in methods:
    for dim in dims:
        filename = f"{method}-{dim}.pt"
        filepath = os.path.join(results_dir, filename)
        if os.path.exists(filepath):
            data = torch.load(filepath)
            lds_data[method].append(data["lds"])
            proj_time_data[method].append(data["proj_time"])
            damping = data["best_damping"]
            print(f"Setting: {method}-{dim}: with damping {damping} (projection time {data['proj_time']:.2f} seconds)")
        else:
            print(f"Warning: {filepath} not found!")
            # Fill in with NaN or some placeholder
            lds_data[method].append(np.nan)
            proj_time_data[method].append(np.nan)

# Colors for methods
colors = {
    "Random": 'lightcoral',
    "Localize": 'limegreen',
    "SJLT": 'dodgerblue',
    "FJLT": 'purple',
    "Rand-32768_SJLT": 'lightcoral',
    "Rand-32768_Gaussian": 'lightcoral',
    "Rand-131072_SJLT": 'lightcoral',
    "Rand-131072_Gaussian": 'lightcoral',
    "Loc-32768_SJLT": 'limegreen',
    "Loc-32768_Gaussian": 'limegreen',
    "Loc-131072_SJLT": 'limegreen',
    "Loc-131072_Gaussian": 'limegreen',
}
# Out:
# Setting: Random-2048: with damping 1e-07 (projection time 0.10 seconds)
# Setting: Random-4096: with damping 1e-06 (projection time 0.11 seconds)
# Setting: Random-8192: with damping 1e-06 (projection time 0.13 seconds)
# Setting: Localize-2048: with damping 1e-07 (projection time 0.10 seconds)
# Setting: Localize-4096: with damping 1e-06 (projection time 0.09 seconds)
# Setting: Localize-8192: with damping 1e-06 (projection time 0.11 seconds)
# Setting: SJLT-2048: with damping 0.001 (projection time 12.36 seconds)
# Setting: SJLT-4096: with damping 0.001 (projection time 12.24 seconds)
# Setting: SJLT-8192: with damping 0.001 (projection time 17.48 seconds)
# Setting: FJLT-2048: with damping 10.0 (projection time 31.55 seconds)
# Setting: FJLT-4096: with damping 10.0 (projection time 48.17 seconds)
# Setting: FJLT-8192: with damping 10.0 (projection time 81.93 seconds)
# Setting: Loc-32768_SJLT-2048: with damping 1e-05 (projection time 0.31 seconds)
# Setting: Loc-32768_SJLT-4096: with damping 1e-05 (projection time 0.30 seconds)
# Setting: Loc-32768_SJLT-8192: with damping 1e-05 (projection time 0.29 seconds)
# Setting: Loc-32768_Gaussian-2048: with damping 1e-05 (projection time 0.89 seconds)
# Setting: Loc-32768_Gaussian-4096: with damping 1e-05 (projection time 1.36 seconds)
# Setting: Loc-32768_Gaussian-8192: with damping 1e-05 (projection time 2.51 seconds)
# Setting: Loc-131072_SJLT-2048: with damping 0.0001 (projection time 0.79 seconds)
# Setting: Loc-131072_SJLT-4096: with damping 0.0001 (projection time 0.76 seconds)
# Setting: Loc-131072_SJLT-8192: with damping 0.0001 (projection time 0.77 seconds)
# Setting: Loc-131072_Gaussian-2048: with damping 0.0001 (projection time 3.04 seconds)
# Setting: Loc-131072_Gaussian-4096: with damping 0.0001 (projection time 4.78 seconds)
# Setting: Loc-131072_Gaussian-8192: with damping 0.0001 (projection time 9.35 seconds)
# Setting: Rand-32768_SJLT-2048: with damping 1e-05 (projection time 0.37 seconds)
# Setting: Rand-32768_SJLT-4096: with damping 1e-05 (projection time 0.36 seconds)
# Setting: Rand-32768_SJLT-8192: with damping 1e-05 (projection time 0.40 seconds)
# Setting: Rand-32768_Gaussian-2048: with damping 1e-05 (projection time 0.96 seconds)
# Setting: Rand-32768_Gaussian-4096: with damping 1e-05 (projection time 1.47 seconds)
# Setting: Rand-32768_Gaussian-8192: with damping 1e-05 (projection time 2.59 seconds)
# Setting: Rand-131072_SJLT-2048: with damping 0.0001 (projection time 1.27 seconds)
# Setting: Rand-131072_SJLT-4096: with damping 0.0001 (projection time 1.24 seconds)
# Setting: Rand-131072_SJLT-8192: with damping 0.0001 (projection time 1.27 seconds)
# Setting: Rand-131072_Gaussian-2048: with damping 0.0001 (projection time 3.52 seconds)
# Setting: Rand-131072_Gaussian-4096: with damping 0.0001 (projection time 5.27 seconds)
# Setting: Rand-131072_Gaussian-8192: with damping 1e-05 (projection time 10.10 seconds)

# %%
# Bar plot setup
x = np.arange(len(dims))  # one x location per projection dimension
width = 0.2  # Adjusted to fit 4 bars

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Calculate bar positions for 4 methods
pos1 = x - 1.5*width
pos2 = x - 0.5*width
pos3 = x + 0.5*width
pos4 = x + 1.5*width

# LDS subplot
axs[0].bar(pos1, lds_data["Random"], width, label="Random", color=colors["Random"])
axs[0].bar(pos2, lds_data["Localize"], width, label="Localize", color=colors["Localize"])
axs[0].bar(pos3, lds_data["SJLT"], width, label="SJLT", color=colors["SJLT"])
axs[0].bar(pos4, lds_data["FJLT"], width, label="FJLT", color=colors["FJLT"])
axs[0].set_title("LDS by Projection Dimension")
axs[0].set_xlabel("Projection Dimension")
axs[0].set_ylabel("LDS")
axs[0].set_xticks(x)
axs[0].set_xticklabels(dims)
axs[0].set_ylim(0.1, 0.5)
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

# Projection Time subplot
axs[1].bar(pos1, proj_time_data["Random"], width, color=colors["Random"])
axs[1].bar(pos2, proj_time_data["Localize"], width, color=colors["Localize"])
axs[1].bar(pos3, proj_time_data["SJLT"], width, color=colors["SJLT"])
axs[1].bar(pos4, proj_time_data["FJLT"], width, color=colors["FJLT"])
axs[1].set_title("Projection Time by Projection Dimension")
axs[1].set_xlabel("Projection Dimension")
axs[1].set_ylabel("Projection Time (s)")
axs[1].set_xticks(x)
axs[1].set_xticklabels(dims)
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Add shared legend
fig.legend(["Random", "Localize", "SJLT", "FJLT"], loc='upper center', ncol=4, bbox_to_anchor=(0.5, 0.03))

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for legend
plt.show()

# %%
# Bar plot setup
x = np.arange(len(dims))  # one x location per projection dimension
width = 0.25  # Adjusted to fit 3 bars

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Calculate bar positions for 3 methods
pos1 = x - width
pos2 = x
pos3 = x + width

# LDS subplot
axs[0].bar(pos1, lds_data["Loc-32768_SJLT"], width, label="Loc-32768_SJLT", color=colors["Loc-32768_SJLT"])
axs[0].bar(pos2, lds_data["Rand-32768_SJLT"], width, label="Rand-32768_SJLT", color=colors["Rand-32768_SJLT"])
axs[0].bar(pos3, lds_data["SJLT"], width, label="SJLT", color=colors["SJLT"])
axs[0].set_title("LDS by Projection Dimension")
axs[0].set_xlabel("Projection Dimension")
axs[0].set_ylabel("LDS")
axs[0].set_xticks(x)
axs[0].set_xticklabels(dims)
axs[0].set_ylim(0.1, 0.5)
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

# Projection Time subplot
axs[1].bar(pos1, proj_time_data["Loc-32768_SJLT"], width, color=colors["Loc-32768_SJLT"])
axs[1].bar(pos2, proj_time_data["Rand-32768_SJLT"], width, color=colors["Rand-32768_SJLT"])
axs[1].bar(pos3, proj_time_data["SJLT"], width, color=colors["SJLT"])
axs[1].set_title("Projection Time by Projection Dimension")
axs[1].set_xlabel("Projection Dimension")
axs[1].set_ylabel("Projection Time (s)")
axs[1].set_xticks(x)
axs[1].set_xticklabels(dims)
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Add shared legend
fig.legend(["Random$\\to$SJLT", "Localize$\\to$SJLT", "SJLT"], loc='upper center', ncol=3, bbox_to_anchor=(0.5, 0.03))

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for legend
plt.show()

# %%
# Bar plot setup
x = np.arange(len(dims))  # one x location per projection dimension
width = 0.25  # Adjusted to fit 3 bars

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Calculate bar positions for 3 methods
pos1 = x - width
pos2 = x
pos3 = x + width

# LDS subplot
axs[0].bar(pos1, lds_data["Rand-131072_SJLT"], width, label="Rand-131072_SJLT", color=colors["Rand-131072_SJLT"])
axs[0].bar(pos2, lds_data["Loc-131072_SJLT"], width, label="Loc-131072_SJLT", color=colors["Loc-131072_SJLT"])
axs[0].bar(pos3, lds_data["SJLT"], width, label="SJLT", color=colors["SJLT"])
axs[0].set_title("LDS by Projection Dimension")
axs[0].set_xlabel("Projection Dimension")
axs[0].set_ylabel("LDS")
axs[0].set_xticks(x)
axs[0].set_xticklabels(dims)
axs[0].set_ylim(0.1, 0.5)
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

# Projection Time subplot
axs[1].bar(pos1, proj_time_data["Rand-131072_SJLT"], width, label="Rand-131072_SJLT", color=colors["Rand-131072_SJLT"])
axs[1].bar(pos2, proj_time_data["Loc-131072_SJLT"], width, label="Loc-131072_SJLT", color=colors["Loc-131072_SJLT"])
axs[1].bar(pos3, proj_time_data["SJLT"], width, label="SJLT", color=colors["SJLT"])
axs[1].set_title("Projection Time by Projection Dimension")
axs[1].set_xlabel("Projection Dimension")
axs[1].set_ylabel("Projection Time (s)")
axs[1].set_xticks(x)
axs[1].set_xticklabels(dims)
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Add shared legend
fig.legend(["Random$\\to$SJLT", "Localize$\\to$SJLT", "SJLT"], loc='upper center', ncol=3, bbox_to_anchor=(0.5, 0.03))

plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for legend
plt.show()
